# %%
from datetime import datetime

# datetime object containing current date and time
now = datetime.now()
print("  Y   M  D  H Mi  S  Ms")
print(now)
# Out:
#   Y   M  D  H Mi  S  Ms
# 2022-01-10 05:04:54.811561
